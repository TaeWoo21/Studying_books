# %%
#-*- coding: utf-8 -*-

import numpy as np
import pandas as pd

# %%
crime_anal_police = pd.read_csv('./data/2015년.csv', thousands=',', encoding='utf-8')
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861

# %%
import googlemaps

# %%
gmaps_key = "AIzaSyCuYaDDRE0gwTYSlV4qW9-T-sWerRm3HvI"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
a = gmaps.geocode('서울중부경찰서', language='ko')

# %%
a
# Out:
# [{u'address_components': [{u'long_name': u'\uff12\uff17',
#     u'short_name': u'\uff12\uff17',
#     u'types': [u'premise']},
#    {u'long_name': u'\uc218\ud45c\ub85c',
#     u'short_name': u'\uc218\ud45c\ub85c',
#     u'types': [u'political', u'sublocality', u'sublocality_level_4']},
#    {u'long_name': u'\uc744\uc9c0\ub85c\ub3d9',
#     u'short_name': u'\uc744\uc9c0\ub85c\ub3d9',
#     u'types': [u'political', u'sublocality', u'sublocality_level_2']},
#    {u'long_name': u'\uc911\uad6c',
#     u'short_name': u'\uc911\uad6c',
#     u'types': [u'political', u'sublocality', u'sublocality_level_1']},
#    {u'long_name': u'\uc11c\uc6b8\ud2b9\ubcc4\uc2dc',
#     u'short_name': u'\uc11c\uc6b8\ud2b9\ubcc4\uc2dc',
#     u'types': [u'administrative_area_level_1', u'political']},
#    {u'long_name': u'\ub300\ud55c\ubbfc\uad6d',
#     u'short_name': u'KR',
#     u'types': [u'country', u'political']},
#    {u'long_name': u'100-032',
#     u'short_name': u'100-032',
# ...

# %%
print repr(a).decode('unicode_escape')
# Out:
# [{u'geometry': {u'location': {u'lat': 37.5636465, u'lng': 126.9895796}, u'viewport': {u'northeast': {u'lat': 37.56499548029149, u'lng': 126.9909285802915}, u'southwest': {u'lat': 37.56229751970849, u'lng': 126.9882306197085}}, u'location_type': u'ROOFTOP'}, u'place_id': u'ChIJc-9q5uSifDURLhQmr5wkXmc', u'plus_code': {u'global_code': u'8Q98HX7Q+FR', u'compound_code': u'HX7Q+FR 대한민국 서울특별시'}, u'address_components': [{u'long_name': u'２７', u'types': [u'premise'], u'short_name': u'２７'}, {u'long_name': u'수표로', u'types': [u'political', u'sublocality', u'sublocality_level_4'], u'short_name': u'수표로'}, {u'long_name': u'을지로동', u'types': [u'political', u'sublocality', u'sublocality_level_2'], u'short_name': u'을지로동'}, {u'long_name': u'중구', u'types': [u'political', u'sublocality', u'sublocality_level_1'], u'short_name': u'중구'}, {u'long_name': u'서울특별시', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'서울특별시'}, {u'long_name': u'대한민국', u'types': [u'country', u'political'], u's
# ...

# %%
station_name = []

for name in crime_anal_police[u'관서명']:
    station_name.append(unicode('서울' + str(name[:-1]) + '경찰서'))

station_name
# Out:
# [u'\uc11c\uc6b8\uc911\ubd80\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc885\ub85c\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\ub0a8\ub300\ubb38\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc11c\ub300\ubb38\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\ud61c\ud654\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc6a9\uc0b0\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc131\ubd81\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\ub3d9\ub300\ubb38\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\ub9c8\ud3ec\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc601\ub4f1\ud3ec\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc131\ub3d9\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\ub3d9\uc791\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uad11\uc9c4\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc11c\ubd80\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uac15\ubd81\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uae08\ucc9c\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uc911\ub791\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uac15\ub0a8\uacbd\ucc30\uc11c',
#  u'\uc11c\uc6b8\uad00\uc545\uacbd\ucc30\uc11c',
# ...

# %%
print repr(station_name).decode('unicode_escape')
# Out:
# [u'서울중부경찰서', u'서울종로경찰서', u'서울남대문경찰서', u'서울서대문경찰서', u'서울혜화경찰서', u'서울용산경찰서', u'서울성북경찰서', u'서울동대문경찰서', u'서울마포경찰서', u'서울영등포경찰서', u'서울성동경찰서', u'서울동작경찰서', u'서울광진경찰서', u'서울서부경찰서', u'서울강북경찰서', u'서울금천경찰서', u'서울중랑경찰서', u'서울강남경찰서', u'서울관악경찰서', u'서울강서경찰서', u'서울강동경찰서', u'서울종암경찰서', u'서울구로경찰서', u'서울서초경찰서', u'서울양천경찰서', u'서울송파경찰서', u'서울노원경찰서', u'서울방배경찰서', u'서울은평경찰서', u'서울도봉경찰서', u'서울수서경찰서']

# %%
station_address = []
station_lat = []
station_lng = []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    station_address.append(tmp[0].get("formatted_address"))
    
    tmp_loc = tmp[0].get("geometry")
    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    
    print(name + '-->' + tmp[0].get("formatted_address"))
# Out:
# 서울중부경찰서-->대한민국 서울특별시 중구 을지로동 수표로 27
# 서울종로경찰서-->대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46
# 서울남대문경찰서-->대한민국 서울특별시 중구 남대문로5가 한강대로 410
# 서울서대문경찰서-->대한민국 서울특별시 서대문구 미근동 통일로 113
# 서울혜화경찰서-->대한민국 서울특별시 종로구 종로1.2.3.4가동 창경궁로 112-16
# 서울용산경찰서-->대한민국 서울특별시 용산구 원효로1가 25
# 서울성북경찰서-->대한민국 서울특별시 성북구 삼선동5가 301
# 서울동대문경찰서-->대한민국 서울특별시 동대문구 청량리동 약령시로21길 29
# 서울마포경찰서-->대한민국 서울특별시 마포구 아현동 618-1
# 서울영등포경찰서-->대한민국 서울특별시 영등포구 영등포동 영등포로46길 14
# 서울성동경찰서-->대한민국 서울특별시 성동구 행당1동 왕십리광장로 9
# 서울동작경찰서-->대한민국 서울특별시 동작구 노량진1동 노량진로 148
# 서울광진경찰서-->대한민국 서울특별시 광진구 구의1동 자양로 167
# 서울서부경찰서-->대한민국 서울특별시 은평구 대조동 통일로 757
# 서울강북경찰서-->대한민국 서울특별시 강북구 번1동 오패산로 406
# 서울금천경찰서-->대한민국 서울특별시 관악구 신림동 남부순환로 1435
# 서울중랑경찰서-->대한민국 서울특별시 중랑구 신내1동 신내역로3길 40-10
# 서울강남경찰서-->대한민국 서울특별시 강남구 대치동 998
# 서울관악경찰서-->대한민국 서울특별시 관악구 봉천동
# 서울강서경찰서-->대한민국 서울특별시 양천구 신월동 화곡로 73
# 서울강동경찰서-->대한민국 서울특별시 강동구 성내1동 성내로 57
# 서울종암경찰서-->대한민국 서울특별시 성북구 종암동 종암로 135
# 서울구로경찰서-->대한민국 서울특별시 구로구 가마산로 235
# 서울서초경찰서-->대한민국 서울특별시 서초구 서초3동 반포대로 179
# ...

# %%
print repr(station_address).decode('unicode_escape')
# Out:
# [u'대한민국 서울특별시 중구 을지로동 수표로 27', u'대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46', u'대한민국 서울특별시 중구 남대문로5가 한강대로 410', u'대한민국 서울특별시 서대문구 미근동 통일로 113', u'대한민국 서울특별시 종로구 종로1.2.3.4가동 창경궁로 112-16', u'대한민국 서울특별시 용산구 원효로1가 25', u'대한민국 서울특별시 성북구 삼선동5가 301', u'대한민국 서울특별시 동대문구 청량리동 약령시로21길 29', u'대한민국 서울특별시 마포구 아현동 618-1', u'대한민국 서울특별시 영등포구 영등포동 영등포로46길 14', u'대한민국 서울특별시 성동구 행당1동 왕십리광장로 9', u'대한민국 서울특별시 동작구 노량진1동 노량진로 148', u'대한민국 서울특별시 광진구 구의1동 자양로 167', u'대한민국 서울특별시 은평구 대조동 통일로 757', u'대한민국 서울특별시 강북구 번1동 오패산로 406', u'대한민국 서울특별시 관악구 신림동 남부순환로 1435', u'대한민국 서울특별시 중랑구 신내1동 신내역로3길 40-10', u'대한민국 서울특별시 강남구 대치동 998', u'대한민국 서울특별시 관악구 봉천동', u'대한민국 서울특별시 양천구 신월동 화곡로 73', u'대한민국 서울특별시 강동구 성내1동 성내로 57', u'대한민국 서울특별시 성북구 종암동 종암로 135', u'대한민국 서울특별시 구로구 가마산로 235', u'대한민국 서울특별시 서초구 서초3동 반포대로 179', u'대한민국 서울특별시 양천구 신정6동 목동동로 99', u'대한민국 서울특별시 송파구 가락본동 9', u'대한민국 서울특별시 노원구 하계동 노원로 283', u'대한민국 서울특별시 서초구 방배동 동작대로 204', u'대한민국 서울특별시 은평구 불광2동 연서로 365', u'대한민국 서울특별시 도봉구 창4동 노해로 403', u'대한민국 서울특별시 강남구 개포동 개포로 617']

# %%
station_lat
# Out:
# [37.5636465,
#  37.5755578,
#  37.5547584,
#  37.5647848,
#  37.5718529,
#  37.538649,
#  37.5897482,
#  37.58506149999999,
#  37.550814,
#  37.5179839,
#  37.5617309,
#  37.5130866,
#  37.542873,
#  37.6128611,
#  37.63730390000001,
#  37.4813631,
#  37.618692,
#  37.5094352,
#  37.4743789,
#  37.5397827,
#  37.528511,
#  37.6020592,
#  37.494931,
#  37.4956054,
#  37.5165667,
#  37.5019065,
#  37.6423605,
#  37.4945959,
#  37.6283597,
#  37.6533589,
#  37.49349]

# %%
station_lng
# Out:
# [126.9895796,
#  126.9848674,
#  126.9734981,
#  126.9667762,
#  126.9989143,
#  126.966055,
#  127.0161353,
#  127.0457679,
#  126.954028,
#  126.9075056,
#  127.0363806,
#  126.9428498,
#  127.083821,
#  126.9274951,
#  127.0273399,
#  126.9100605,
#  127.1047136,
#  127.0669578,
#  126.9509748,
#  126.8299968,
#  127.1268224,
#  127.0321577,
#  126.886731,
#  127.0052504,
#  126.8656763,
#  127.1271513,
#  127.0714027,
#  126.9831279,
#  126.9287226,
#  127.052682,
#  127.0772119]

# %%
gu_name = []

for name in station_address:
    tmp = name.split()
    tmp_gu = [gu for gu in tmp if gu[-1] == '구'][0]
    
    gu_name.append(tmp_gu)

crime_anal_police['구별'] = gu_name
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구별
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
crime_anal_police[crime_anal_police[u'관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#      구별
# 15  관악구

# %%
crime_anal_police.loc[crime_anal_police[u'관서명']=='금천서', ['구별']] = '금천구'

# %%
crime_anal_police[crime_anal_police[u'관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#      구별
# 15  금천구

# %%
crime_anal_police.to_csv("./data/crime_in_Seoul_include_gu_name.csv", sep=',', encoding='utf-8')

# %%
crime_anal_raw = pd.read_csv("./data/crime_in_Seoul_include_gu_name.csv", encoding='utf-8')
crime_anal_raw.head()
# Out:
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별
# 0   1355   1170    중구
# 1   1278   1070   종로구
# 2    869    794    중구
# 3   2056   1711  서대문구
# 4   1015    861   종로구

# %%
crime_anal_raw = pd.read_csv("./data/crime_in_Seoul_include_gu_name.csv", encoding='utf-8', index_col=0)
crime_anal_raw.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구별
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
crime_anal = pd.pivot_table(crime_anal_raw, index=u'구별', aggfunc=np.sum)
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    221    320     14     12      8      9    827   2706   2642   3298
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625

# %%
crime_anal['강간검거율'] = crime_anal[u'강간 검거']/crime_anal[u'강간 발생']*100
crime_anal['강도검거율'] = crime_anal[u'강도 검거']/crime_anal[u'강도 발생']*100
crime_anal['살인검거율'] = crime_anal[u'살인 검거']/crime_anal[u'살인 발생']*100
crime_anal['절도검거율'] = crime_anal[u'절도 검거']/crime_anal[u'절도 발생']*100
crime_anal['폭력검거율'] = crime_anal[u'폭력 검거']/crime_anal[u'폭력 발생']*100

del crime_anal[u'강간 검거']
del crime_anal[u'강도 검거']
del crime_anal[u'살인 검거']
del crime_anal[u'절도 검거']
del crime_anal[u'폭력 검거']

crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 관악구    320     12      9   2706   3298  69.062500  116.666667   88.888889
# 광진구    240     14      4   3026   2625  91.666667  185.714286  100.000000
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  30.561715  80.109157
# 광진구  42.200925  83.047619

# %%
con_list = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

for column in con_list:
    crime_anal.loc[crime_anal[column] > 100, column] = 100
    
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  100.000000   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  100.000000
# 관악구    320     12      9   2706   3298  69.062500  100.000000   88.888889
# 광진구    240     14      4   3026   2625  91.666667  100.000000  100.000000
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  30.561715  80.109157
# 광진구  42.200925  83.047619

# %%
crime_anal.rename(columns = {u'강간 발생':'강간',
                             u'강도 발생':'강도',
                             u'살인 발생':'살인',
                             u'절도 발생':'절도',
                             u'폭력 발생':'폭력'}, inplace=True)
crime_anal.head()
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구  449  21  13  3850  4284  77.728285   85.714286   76.923077  42.857143
# 강동구  156   6   4  2366  2712  78.846154  100.000000   75.000000  33.347422
# 강북구  153  14   7  1434  2649  82.352941   92.857143  100.000000  43.096234
# 관악구  320  12   9  2706  3298  69.062500  100.000000   88.888889  30.561715
# 광진구  240  14   4  3026  2625  91.666667  100.000000  100.000000  42.200925
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# 관악구  80.109157
# 광진구  83.047619

# %%
from sklearn import preprocessing

col = ['강간', '강도', '살인', '절도', '폭력']

x = crime_anal[col].values
min_max_scaler = preprocessing.MinMaxScaler()

x_scaled = min_max_scaler.fit_transform(x.astype(float))
crime_anal_norm = pd.DataFrame(x_scaled, columns=col, index=crime_anal.index)

col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_norm[col2] = crime_anal[col2]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 관악구   88.888889  30.561715  80.109157
# 광진구  100.000000  42.200925  83.047619

# %%
result_CCTV = pd.read_csv('./data/CCTV_result.csv', encoding='UTF-8', index_col='구별')
crime_anal_norm[[u'인구수', u'CCTV']] = result_CCTV[[u'인구수', u'소계']]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율  CCTV     인구수
# 구별
# 강남구   76.923077  42.857143  86.484594  3238  551888
# 강동구   75.000000  33.347422  82.890855  1010  437050
# 강북구  100.000000  43.096234  88.637222   831  326063
# 관악구   88.888889  30.561715  80.109157  2109  521960
# 광진구  100.000000  42.200925  83.047619   878  370519

# %%
col = ['강간', '강도', '살인', '절도', '폭력']
crime_anal_norm['범죄'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율  CCTV     인구수        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  3238  551888  4.472701
# 강동구   75.000000  33.347422  82.890855  1010  437050  1.116551
# 강북구  100.000000  43.096234  88.637222   831  326063  1.494746
# 관악구   88.888889  30.561715  80.109157  2109  521960  2.613667
# 광진구  100.000000  42.200925  83.047619   878  370519  2.034438

# %%
col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율  CCTV     인구수        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  3238  551888  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  1010  437050  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222   831  326063  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  2109  521960  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619   878  370519  2.034438  416.915211

# %% [markdown]
# # ▶︎ Seaborn 예제

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2*np.sin(x+0.5)
y3 = 3*np.sin(x+1.0)
y4 = 4*np.sin(x+1.5)

sns.set_style("whitegrid")

plt.figure(figsize=(10,6))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.plot(x,y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
plt.show()

# %%
sns.set_style("darkgrid")
sns.lmplot(x="total_bill", y="tip", data=tips, size=7)
plt.show()

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", palette="Set1", data=tips, size=7)
plt.show()

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights
flights = flights.pivot("month","year","passengers")
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt='d')
plt.show()

# %%
sns.set(style="ticks")
iris = sns.load_dataset("iris")
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.pairplot(iris, hue="species")
plt.show()

# %% [markdown]
# # ▶︎ 범죄 데이터 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~')

# %%
sns.pairplot(crime_anal_norm, vars=['강도', '살인', '폭력'], kind='reg', size=3)
plt.show()

# %%
sns.pairplot(crime_anal_norm, x_vars=[u'인구수', u'CCTV'], y_vars=['살인', '강도'], kind='reg', size=3)
plt.show()

# %%
sns.pairplot(crime_anal_norm, x_vars=[u'인구수', u'CCTV'], y_vars=['살인검거율', '폭력검거율'], kind='reg', size=3)
plt.show()

# %%
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율  CCTV     인구수        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  3238  551888  4.472701
# 강동구   75.000000  33.347422  82.890855  1010  437050  1.116551
# 강북구  100.000000  43.096234  88.637222   831  326063  1.494746
# 관악구   88.888889  30.561715  80.109157  2109  521960  2.613667
# 광진구  100.000000  42.200925  83.047619   878  370519  2.034438

# %%
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거'] / tmp_max * 100
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  강도검거율  \
# 구별
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000  100.0
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702  100.0
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667  100.0
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064  100.0
# 용산구   0.265130  0.529412  0.250000  0.169004  0.133128   89.175258  100.0
#
#       살인검거율      절도검거율      폭력검거율  CCTV     인구수        범죄          검거
# 구별
# 도봉구   100.0  44.967074  87.626093   825  344096  0.318627  100.000000
# 금천구   100.0  56.668794  86.465433  1348  252752  0.589867   97.997139
# 광진구   100.0  42.200925  83.047619   878  370519  2.034438   96.375820
# 동대문구  100.0  41.090358  87.401884  1870  364527  1.490147   95.444250
# 용산구   100.0  37.700706  83.121951  2096  245245  1.346674   94.776790

# %%
target_col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
plt.figure(figsize = (10, 10))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', linewidths=.5)
plt.title('범죄 검거 비율(정규화된 검거의 합으로 정렬)')
plt.show()

# %%
target_col = ['강간', '강도', '살인', '절도', '폭력', '범죄']

crime_anal_norm['범죄'] = crime_anal_norm['범죄'] / 5
crime_anal_norm_sort = crime_anal_norm.sort_values(by='범죄', ascending=False)
plt.figure(figsize = (10, 10))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', linewidths=.5)
plt.title('범죄비율 (정규화된 발생 건수로 정렬)')
plt.show()

# %%
crime_anal_norm.to_csv('./data/crime_in_Seoul_final.csv', sep=',', encoding='utf-8')

# %% [markdown]
# # ▶︎ 지도 시각화 도구 Folium

# %%
import folium

# %%
map_osm = folium.Map(location=[45.5236, -122.6750])
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd

state_unemployment = './data/folium_US_Unemployment_Oct2012.csv'

state_data = pd.read_csv(state_unemployment)
state_data.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo = './data/folium_us-states.json'

map = folium.Map(location=[40, -98], zoom_start=4)
map.choropleth(geo_data=state_geo, data=state_data, columns=['State', 'Unemployment'], key_on='feature.id', fill_color='YlGn', legend_name='Unemployment Rate(%)')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo_path = './data/skorea_municipalities_geo_simple.json'

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_path, data=crime_anal_norm['강간'], columns=[crime_anal_norm.index, crime_anal_norm['강간']], fill_color='PuRd', key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
